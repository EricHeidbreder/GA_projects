# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
houses_train_clean = pd.read_csv('../datasets/cleaned/houses_train_clean.csv')
houses_test_clean = pd.read_csv('../datasets/cleaned/houses_test_clean.csv')

# %%
houses_train_clean['age_of_garage'].describe()
# Out:
# count    2048.000000
# mean       29.690430
# std        25.255081
# min         0.000000
# 25%         6.000000
# 50%        25.000000
# 75%        48.000000
# max       115.000000
# Name: age_of_garage, dtype: float64

# %%
sns.pairplot(houses_train_clean[['Overall Qual', 'Overall Qual x Gr Liv Area', 'log_gr_liv_area', 'age_of_garage', 'SalePrice']]);
