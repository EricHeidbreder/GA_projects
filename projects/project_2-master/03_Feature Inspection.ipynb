# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
houses_train_cleaned = pd.read_csv('./datasets/cleaned/house_train_cleaned.csv')
houses_train_cleaned
# Out:
#         Id        PID  MS SubClass MS Zoning  Lot Frontage Street Alley  \
# 0      109  533352170           60        RL           0.0   Pave   NaN
# 1      544  531379050           60        RL          43.0   Pave   NaN
# 2      153  535304180           20        RL          68.0   Pave   NaN
# 3      318  916386060           60        RL          73.0   Pave   NaN
# 4      255  906425045           50        RL          82.0   Pave   NaN
# ...    ...        ...          ...       ...           ...    ...   ...
# 2029  1587  921126030           20        RL          79.0   Pave   NaN
# 2030   785  905377130           30        RL           0.0   Pave   NaN
# 2031   916  909253010           50        RL          57.0   Pave   NaN
# 2032   639  535179160           20        RL          80.0   Pave   NaN
# 2033    10  527162130           60        RL          60.0   Pave   NaN
#
#      Lot Shape Land Contour Utilities  ... Garage Cond_NA Garage Cond_Po  \
# ...

# %%
sns.pairplot(houses_train_cleaned[['total_house_sf_x_overall_qual', 'Mas Vnr Area', 'SalePrice']])

# %%
houses_train_cleaned.groupby('Year Built').mean()['SalePrice'].plot(kind='bar', figsize=(25,5))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-31eb8861b299> in <module>
# ----> 1 houses_train_cleaned.groupby('Year Built').mean()['SalePrice'].plot(kind='bar', figsize=(25,5))
#
# C:\ProgramData\Anaconda3\envs\dsi\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed)
#    5808             group_keys=group_keys,
#    5809             squeeze=squeeze,
# -> 5810             observed=observed,
#    5811         )
#    5812
#
# C:\ProgramData\Anaconda3\envs\dsi\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated)
#     408                 sort=sort,
#     409                 observed=observed,
# --> 410                 mutated=self.mutated,
#     411             )
# ...

# %%
houses_train_cleaned
# Out:
#         Id        PID  MS SubClass MS Zoning  Lot Frontage Street Alley  \
# 0      109  533352170           60        RL           0.0   Pave   NaN
# 1      544  531379050           60        RL          43.0   Pave   NaN
# 2      153  535304180           20        RL          68.0   Pave   NaN
# 3      318  916386060           60        RL          73.0   Pave   NaN
# 4      255  906425045           50        RL          82.0   Pave   NaN
# ...    ...        ...          ...       ...           ...    ...   ...
# 2029  1587  921126030           20        RL          79.0   Pave   NaN
# 2030   785  905377130           30        RL           0.0   Pave   NaN
# 2031   916  909253010           50        RL          57.0   Pave   NaN
# 2032   639  535179160           20        RL          80.0   Pave   NaN
# 2033    10  527162130           60        RL          60.0   Pave   NaN
#
#      Lot Shape Land Contour Utilities  ... Garage Cond_NA Garage Cond_Po  \
# ...
